# %% [markdown]
# **Nama Lengkap:** Yudi Karma
# **NIM:** 250401020118
# **Kelas:** IF207

# %% [markdown]
# # PERTEMUAN 1: Notebook Pertama Data Science

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel dan tipe data dasar
nama       = "Yudi Karma"
angkatan   = 2024
ipk        = 3.75
aktif      = True

print(f"Nama    : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK     : {ipk}")
print(f"Aktif   : {aktif}")

# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")

# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Yudi Karma", "Informatika", 2024)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama    : Yudi Karma
# Angkatan: 2024
# IPK     : 3.75
# Aktif   : True
#
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub
# Hai! Saya Yudi Karma dari Informatika, angkatan 2024.

# %% [markdown]
# **Kesimpulan**
#
# Pada pertemuan ini dipelajari penggunaan notebook Python dasar untuk menampilkan output, membuat variabel, menggunakan list dan perulangan, serta membuat fungsi sederhana. Temuan utama adalah notebook dapat dipakai untuk menggabungkan kode dan dokumentasi dalam satu file kerja. Keterbatasan pada tahap ini adalah materi masih dasar dan belum masuk ke pengolahan dataset.
